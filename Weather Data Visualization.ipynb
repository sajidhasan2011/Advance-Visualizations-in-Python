# %%
import pandas as pd
import seaborn as sns

# %%
weather = pd.read_csv('Weather Dataset - Trial Activity DataSet.csv (1).csv')

# %%
weather.head(10)
# Out:
#           date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  18-05-2017 00:00         NaN                   73        63           1
# 1  18-05-2017 00:00         NaN                  251        63           1
# 2  18-05-2017 00:00         NaN                   75        56           1
# 3  18-05-2017 01:00         NaN                   98        56           1
# 4  18-05-2017 01:00         NaN                  283        56           1
# 5  18-05-2017 02:00         NaN                  115        49           1
# 6  18-05-2017 02:00         NaN                   48        49           1
# 7  18-05-2017 02:00         NaN                  133        49           1
# 8  18-05-2017 03:00         NaN                  130        60           2
# 9  18-05-2017 03:00         NaN                   93        60           2
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            199 non-null    object
#  1   is_holiday           0 non-null      float64
#  2   air_pollution_index  199 non-null    int64
#  3   humidity             199 non-null    int64
#  4   wind_speed           199 non-null    int64
#  5   wind_direction       199 non-null    int64
#  6   visibility_in_miles  199 non-null    int64
#  7   dew_point            199 non-null    int64
#  8   temperature          199 non-null    float64
#  9   rain_p_h             199 non-null    int64
#  10  snow_p_h             199 non-null    int64
#  11  clouds_all           199 non-null    int64
#  12  weather_type         199 non-null    object
#  13  weather_description  199 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 21.9+ KB

# %%
sns.barplot(weather['wind_speed'])
sns.barplot(weather['temperature'])
# Out:
# <Axes: ylabel='wind_speed'>

# %%
sns.distplot(weather['temperature'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30880\3314857965.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(weather['temperature'])
# <Axes: xlabel='temperature', ylabel='Density'>

# %%
sns.distplot(weather['humidity'],rug=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30880\4014892966.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(weather['humidity'],rug=True)
# <Axes: xlabel='humidity', ylabel='Density'>

# %%
sns.jointplot(weather['humidity'],kind="hex")
sns.jointplot(weather['temperrature'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 sns.jointplot(weather['humidity'],kind="hex")
# ...

# %%
sns.jointplot(weather['humidity'],kind="hex")
sns.jointplot(weather['temperrature'],kind="hex")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 sns.jointplot(weather['humidity'],kind="hex")
# ...

# %%
sns.jointplot(weather['humidity'],kind='kde')
sns.jointplot(weather['temperrature'],kind="kde")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 sns.jointplot(weather['humidity'],kind='kde')
# ...

# %%
sns.pairplot(weather[['humidity','temperrature','air_pollution_index']])

# %%
sns.stripplot(weather['humidity'])
sns.stripplot(weather['temperrature'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 sns.stripplot(weather['humidity'])
# ...

# %%
sns.stripplot(weather['weather type'],jitter=True)
sns.stripplot(weather['temperrature'],jitter=True)

# %%
sns.swarmplot(weather['humidity'])
sns.swarmplot(weather['temperrature'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 sns.swarmplot(weather['humidity'])
# ...

# %%
sns.boxplot(weather['humidity'],weather['temperrature'],hue=weather['weather type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ...

# %%
sns.barplot(weather['humidity'],weather['temperrature'],hue=weather['weather type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ...

# %%
sns.countplot(weather['weather type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weather type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.countplot(weather['weather type'])
#
# ...

# %%
sns.pointplot(weather['humidity'],weather['temperrature'],hue=weather['weather type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temperrature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ...

# %%
sns.lmplot(x="humidity",y="temperrature",data=weather)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sns.lmplot(x="humidity",y="temperrature",data=weather)
#
# File F:\Lib\site-packages\seaborn\regression.py:611, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     609 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     610 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 611 data = data[cols]
#     613 # Initialize the grid
#     614 facets = FacetGrid(
#     615     data, row=row, col=col, hue=hue,
#     616     palette=palette,
#    (...)
# ...

# %%
sns.lmplot(x="humidity",y="temperrature",hue="weather_type",data=weather)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.lmplot(x="humidity",y="temperrature",hue="weather_type",data=weather)
#
# File F:\Lib\site-packages\seaborn\regression.py:611, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     609 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     610 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 611 data = data[cols]
#     613 # Initialize the grid
#     614 facets = FacetGrid(
#     615     data, row=row, col=col, hue=hue,
#     616     palette=palette,
#    (...)
# ...
